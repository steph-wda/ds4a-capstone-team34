# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading datasets
education_df = pd.read_csv('data/Education.csv',skiprows=1)
education_df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  2005
# 1                    1  Total, all countries or areas  2005
# 2                    1  Total, all countries or areas  2005
# 3                    1  Total, all countries or areas  2005
# 4                    1  Total, all countries or areas  2005
#
#                                               Series    Value Footnotes  \
# 0  Students enrolled in primary education (thousa...  679,014       NaN
# 1            Gross enrollment ratio - Primary (male)    104.5       NaN
# 2          Gross enrollment ratio - Primary (female)     99.7       NaN
# 3  Students enrolled in secondary education (thou...  509,277       NaN
# 4          Gross enrollment ratio - Secondary (male)     65.8       NaN
#
#                                               Source
# 0  United Nations Educational, Scientific and Cul...
# 1  United Nations Educational, Scientific and Cul...
# ...

# %%
public_edu_expend_df = pd.read_csv('data/Public expenditure on education.csv',skiprows=1)
public_edu_expend_df.head()
# Out:
#    Region/Country/Area   Unnamed: 1  Year  \
# 0                    4  Afghanistan  2010
# 1                    4  Afghanistan  2010
# 2                    4  Afghanistan  2010
# 3                    4  Afghanistan  2010
# 4                    4  Afghanistan  2015
#
#                                               Series  Value Footnotes  \
# 0  Current expenditure other than staff compensat...    9.3       NaN
# 1  All staff compensation as % of total expenditu...   72.4       NaN
# 2  Capital expenditure as % of total expenditure ...   18.3       NaN
# 3         Public expenditure on education (% of GDP)    3.5       NaN
# 4  Current expenditure other than staff compensat...    9.0       NaN
#
#                                               Source
# 0  United Nations Educational, Scientific and Cul...
# 1  United Nations Educational, Scientific and Cul...
# 2  United Nations Educational, Scientific and Cul...
# 3  United Nations Educational, Scientific and Cul...
# ...

# %%
gdp_df = pd.read_csv('data/GDP and GDP Per Capita.csv', skiprows=1)
gdp_df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  1995
# 1                    1  Total, all countries or areas  2005
# 2                    1  Total, all countries or areas  2010
# 3                    1  Total, all countries or areas  2015
# 4                    1  Total, all countries or areas  2018
#
#                                            Series       Value Footnotes  \
# 0  GDP in current prices (millions of US dollars)  31,247,262       NaN
# 1  GDP in current prices (millions of US dollars)  47,730,924       NaN
# 2  GDP in current prices (millions of US dollars)  66,461,443       NaN
# 3  GDP in current prices (millions of US dollars)  75,133,208       NaN
# 4  GDP in current prices (millions of US dollars)  86,357,998       NaN
#
#                                               Source
# 0  United Nations Statistics Division, New York, ...
# 1  United Nations Statistics Division, New York, ...
# ...

# %%
internet_df = pd.read_csv('data/Internet Usage.csv',skiprows=1)
internet_df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  2000
# 1                    1  Total, all countries or areas  2005
# 2                    1  Total, all countries or areas  2010
# 3                    1  Total, all countries or areas  2015
# 4                    1  Total, all countries or areas  2018
#
#                                          Series  Value  Footnotes  \
# 0  Percentage of individuals using the internet    5.3        NaN
# 1  Percentage of individuals using the internet   15.8  Estimate.
# 2  Percentage of individuals using the internet   28.9  Estimate.
# 3  Percentage of individuals using the internet   40.5  Estimate.
# 4  Percentage of individuals using the internet   49.1  Estimate.
#
#                                               Source
# 0  International Telecommunication Union (ITU), G...
# 1  International Telecommunication Union (ITU), G...
# ...

# %%
patents_df = pd.read_csv('data/Patents.csv',skiprows=1)
patents_df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  1985
# 1                    1  Total, all countries or areas  1995
# 2                    1  Total, all countries or areas  2005
# 3                    1  Total, all countries or areas  2010
# 4                    1  Total, all countries or areas  2018
#
#                        Series      Value Footnotes  \
# 0  Grants of patents (number)    397,580       NaN
# 1  Grants of patents (number)    430,500       NaN
# 2  Grants of patents (number)    633,100       NaN
# 3  Grants of patents (number)    914,200       NaN
# 4  Grants of patents (number)  1,423,000       NaN
#
#                                               Source
# 0  World Intellectual Property Organization (WIPO...
# 1  World Intellectual Property Organization (WIPO...
# 2  World Intellectual Property Organization (WIPO...
# 3  World Intellectual Property Organization (WIPO...
# ...

# %%
research_df = pd.read_csv('data/Research and Development Staff.csv', skiprows=1)
research_df.head()
# Out:
#    Region/Country/Area Unnamed: 1  Year  \
# 0                    8    Albania  2008
# 1                    8    Albania  2008
# 2                    8    Albania  2008
# 3                    8    Albania  2008
# 4                    8    Albania  2008
#
#                                               Series Value      Footnotes  \
# 0  R & D personnel: Total (number in full-time eq...   779  Partial data.
# 1  R & D personnel: Researchers - total (number i...   467  Partial data.
# 2  R & D personnel: Researchers - women (number i...   207  Partial data.
# 3  R & D personnel: Technicians - total (number i...   120  Partial data.
# 4  R & D personnel: Other supporting staff - tota...   192  Partial data.
#
#                                               Source
# 0  United Nations Educational, Scientific and Cul...
# 1  United Nations Educational, Scientific and Cul...
# 2  United Nations Educational, Scientific and Cul...
# 3  United Nations Educational, Scientific and Cul...
# ...

# %%
imports_exports_df = pd.read_csv('data/Total Imports Exports and Balance of Trade.csv',skiprows=1)
imports_exports_df.head()
# Out:
#    Region/Country/Area                     Unnamed: 1  Year  \
# 0                    1  Total, all countries or areas  1995
# 1                    1  Total, all countries or areas  2005
# 2                    1  Total, all countries or areas  2010
# 3                    1  Total, all countries or areas  2015
# 4                    1  Total, all countries or areas  2019
#
#                                  Series System of trade  \
# 0  Imports CIF (millions of US dollars)             NaN
# 1  Imports CIF (millions of US dollars)             NaN
# 2  Imports CIF (millions of US dollars)             NaN
# 3  Imports CIF (millions of US dollars)             NaN
# 4  Imports CIF (millions of US dollars)             NaN
#
#    System of trade footnote       Value Footnotes  \
# 0                       NaN   5,099,057       NaN
# 1                       NaN  10,577,013       NaN
# 2                       NaN  15,275,115       NaN
# 3                       NaN  16,482,346       NaN
# ...
