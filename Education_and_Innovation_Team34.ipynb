# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#show all rows
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Loading datasets and using sample function to pull five random rows to check contents

# %%
#Government Expenditure on Education
url = 'https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/government_edu_expenditure.csv'
gov_edu_expend_df = pd.read_csv(url)
gov_edu_expend_df.sample(n=5)
# Out:
#         NATMON_IND                                          Indicator  \
# 856   XGDP_1_FSGOV  Government expenditure on primary education as...
# 151   X_US_1_FSGOV  Government expenditure on primary education, U...
# 2086  XGDP_2_FSGOV  Government expenditure on lower secondary educ...
# 1831  XGDP_2_FSGOV  Government expenditure on lower secondary educ...
# 930   X_US_2_FSGOV  Government expenditure on lower secondary educ...
#
#      LOCATION              Country  TIME  Time       Value Flag Codes Flags
# 856       RWA               Rwanda  2021  2021     2.61738        NaN   NaN
# 151       NOR               Norway  2019  2019  7754.92242        NaN   NaN
# 2086      ZAF         South Africa  2019  2019     0.67709        NaN   NaN
# 1831      MDA  Republic of Moldova  2020  2020     1.43041        NaN   NaN
# 930       URY              Uruguay  2017  2017   525.98497        NaN   NaN

# %%
#GDP and GDP Per Captia
url = "https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/gdp_and_gdp_per_capita.csv"
gdp_df = pd.read_csv(url)
gdp_df.sample(n=5)
# Out:
#                DEMO_IND                     Indicator LOCATION  \
# 1037  NY_GDP_MKTP_KD_ZG         GDP growth (annual %)      GRC
# 3610     NY_GDP_PCAP_CD  GDP per capita (current US$)      TCA
# 412      NY_GDP_MKTP_CD             GDP (current US$)      DOM
# 1098  NY_GDP_MKTP_KD_ZG         GDP growth (annual %)      NZL
# 747      NY_GDP_MKTP_CD             GDP (current US$)      MAR
#
#                        Country  TIME  Time         Value Flag Codes Flags
# 1037                    Greece  2020  2020 -9.000000e+00        NaN   NaN
# 3610  Turks and Caicos Islands  2018  2018  2.955300e+04        NaN   NaN
# 412         Dominican Republic  2019  2019  8.894130e+10        NaN   NaN
# 1098               New Zealand  2021  2021  4.600000e+00        NaN   NaN
# 747                    Morocco  2021  2021  1.327250e+11        NaN   NaN

# %%
#Internet Usage
url ="https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/internet_usage.csv"
internet_df = pd.read_csv(url)
internet_df.head()
# Out:
#                                         Series Name     Series Code  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
#      Country Name Country Code 1990 [YR1990] 2012 [YR2012] 2016 [YR2016]  \
# 0     Afghanistan          AFG             0   5.454545455            11
# 1         Albania          ALB             0          49.4          59.6
# 2         Algeria          DZA             0          18.2   42.94552688
# 3  American Samoa          ASM             0            ..            ..
# 4         Andorra          AND             0          82.7          89.7
#
#   2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0          13.5          16.8          17.6
# 1          62.4          65.4   68.55039112
# 2   47.69105515   49.03846808          57.9
# 3            ..            ..            ..
# 4   91.56746703            ..            ..

# %%
#Patents in force
url ="https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/patents_in_force.csv"
patents_force_df = pd.read_csv(url,skiprows=6)
patents_force_df.sample(n=5)
# Out:
#                     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3     2016  \
# 22                      Brazil         BR      Total      Total  24153.0
# 7          Antigua and Barbuda         AG      Total      Total      NaN
# 42                     Estonia         EE      Total      Total   8924.0
# 57  Iran (Islamic Republic of)         IR      Total      Total  46552.0
# 66                  Kyrgyzstan         KG      Total      Total    274.0
#
#        2017     2018     2019     2020     2021
# 22  25664.0  31977.0  39538.0  57942.0  75529.0
# 7       NaN     78.0      NaN      NaN      NaN
# 42   9710.0  10452.0  11194.0  11444.0  11768.0
# 57  42447.0  48859.0  53565.0  38642.0      NaN
# 66    256.0    253.0    223.0    194.0    173.0

# %%
#Total Patents Granted
url ="https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/total_patent_grants.csv"
patents_granted_df = pd.read_csv(url,skiprows=6)
patents_granted_df.sample(n=5)
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    2016    2017  \
# 90          Mauritius         MU      Total      Total     2.0     4.0
# 6             Andorra         AD      Total      Total     NaN     4.0
# 108  Papua New Guinea         PG      Total      Total     NaN     NaN
# 157          Zimbabwe         ZW      Total      Total     NaN     NaN
# 19            Belgium         BE      Total      Total  1620.0  1016.0
#
#        2018   2019   2020    2021
# 90      7.0    4.0   17.0     4.0
# 6       6.0   11.0   13.0    12.0
# 108     2.0    4.0    5.0     NaN
# 157    13.0   31.0    6.0    10.0
# 19   1019.0  998.0  994.0  1005.0

# %%
#Research and Development Staff
url = 'https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/rd_staff_headcount.csv' 
research_df = pd.read_csv(url)
research_df.sample(n=5)
# Out:
#      LOCATION   INDICATOR SUBJECT        MEASURE FREQUENCY  TIME  \
# 1570      NOR  RESEARCHER   WOMEN      HEADCOUNT         A  2016
# 2411      ROU  RESEARCHER   WOMEN  PC_RESEARCHER         A  2014
# 2944      POL  RESEARCHER   WOMEN  PC_RESEARCHER         A  2009
# 3036      PRT  RESEARCHER     TOT      HEADCOUNT         A  1991
# 2637      ARG  RESEARCHER   WOMEN      HEADCOUNT         A  2002
#
#              Value  Flag Codes
# 1570  20520.000000         NaN
# 2411     46.010532         NaN
# 2944     39.519177         NaN
# 3036  14109.000000         NaN
# 2637  20888.000000         NaN

# %%
#Total Exports
url = "https://raw.githubusercontent.com/steph-wda/ds4a-capstone-team34/main/data/exports.csv"
imports_exports_df = pd.read_csv(url)
imports_exports_df.sample(n=5)
# Out:
#     Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 249             H5  2017    2017          2017                0             0
# 337             H5  2018    2018          2018                0             0
# 222             H5  2017    2017          2017                0             0
# 561             H4  2017    2017          2017                0             0
# 471             H4  2016    2016          2016                0             0
#
#      Trade Flow Code Trade Flow  Reporter Code         Reporter  ...  Qty  \
# 249                2     Export            558        Nicaragua  ...  0.0
# 337                2     Export            807  North Macedonia  ...  0.0
# 222                2     Export            490  Other Asia, nes  ...  0.0
# 561                2     Export            768             Togo  ...  0.0
# 471                2     Export            585            Palau  ...  NaN
#
#      Alt Qty Unit Code Alt Qty Unit Alt Qty  Netweight (kg)  \
# 249                NaN          NaN     NaN             0.0
# 337                NaN          NaN     NaN             NaN
# 222                NaN          NaN     NaN             0.0
# 561                NaN          NaN     NaN             0.0
# 471                NaN          NaN     NaN             NaN
#
#      Gross weight (kg)  Trade Value (US$)  CIF Trade Value (US$)  \
# 249                NaN       4.925581e+09                    NaN
# 337                NaN       6.906337e+09                    NaN
# 222                NaN       3.176630e+11                    NaN
# 561                NaN       8.670570e+08                    NaN
# 471                NaN       6.539681e+06                    NaN
#
#      FOB Trade Value (US$)  Flag
# 249                    NaN     4
# 337                    NaN     4
# 222                    NaN     4
# 561                    NaN     4
# 471                    NaN     0
#
# [5 rows x 35 columns]

# %% [markdown]
# # Data Cleaning
# - gov_edu_expend_df
#   - Drop "NATMON_IND", "Location", "TIME", "Flag Codes", and "Flags" columns
#   - Rename "Time" column to year
#   - Make all column names lowercase
#   - Rearrange column order to make "country" and "year" column first
#   - Remove years 2020 and 2021 (not enough data points)
#   - Remove countries that do not have data for all years between 2016-2019
#   - Drop NaN values
#   - Pivot to wide format and rename wide_gov_edu_expend_df
#   - Make columns names lowercase and snake case
#   - Reorder the columns
# - gdp_df
#   - Drop "NATMON_IND", "Location", "TIME", "Flag Codes", and "Flags" columns
#   - Rename "Time" column to year
#   - Make all column names lowercase
#   - Rearrange column order to make "country" and "year" column first
#   - Remove years that do not match years in gov_edu_expend_df
#   - Remove countries that do not match countries in gov_edu_expend_df
#   - Pivot to wide format and rename wide_gov_edu_expend_df
#   - Make columns names lowercase and snake case
# - internet_df
#   - Drop ‘Series Code', 'Country Code', '1990 [YR1990]', and '2012 [YR2012]' columns
#   - Rename all columns
#   - Make all column names lowercase
#   - Melt the year columns into one column called years
#   - Rearrange column order to make "country" and "year" column first
#   - Remove rows with ‘..’ value
#   - Remove countries that do not have data for all years between 2016-2019
#   - Find differences in countries and remove them from internet_df, gov_edu_expend_df, and gdp_df
#   - Convert year and values to correct data types
#   - Pivot to wide format and rename wide_internet_df
#   - Make column name lowercase and snake case
# - patents_force_df
#   - Drop ‘Series Code', 'Country Code', '1990 [YR1990]', and '2012 [YR2012]' columns
#   - Rename all columns
#   - Make all column names lowercase
#   - Melt the year columns into one column called years
#   - Rearrange column order to make "country" and "year" column first
#   - Remove rows with ‘..’ value
#   - Remove countries that do not have data for all years between 2016-2019
#   - Find differences in countries and remove them from internet_df, gov_edu_expend_df, and gdp_df
#   - Convert year and values to correct data types
#   - Pivot to wide format and rename wide_internet_df
#   - Make column name lowercase and snake case

# %%
#Checking the shape of the dataset
gov_edu_expend_df.shape
# Out:
# (2221, 9)

# %%
#Checking details of the rows
gov_edu_expend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2221 entries, 0 to 2220
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NATMON_IND  2221 non-null   object
#  1   Indicator   2221 non-null   object
#  2   LOCATION    2221 non-null   object
#  3   Country     2221 non-null   object
#  4   TIME        2221 non-null   int64
#  5   Time        2221 non-null   int64
#  6   Value       2173 non-null   float64
#  7   Flag Codes  66 non-null     object
#  8   Flags       66 non-null     object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 156.3+ KB

# %%
#Dropping unneeded columns
clean_gov_edu_expend_df = gov_edu_expend_df.copy()
clean_gov_edu_expend_df = clean_gov_edu_expend_df.drop(columns=["NATMON_IND", "LOCATION", "TIME", "Flag Codes","Flags"])
clean_gov_edu_expend_df.head()
# Out:
#                                            Indicator  Country  Time  \
# 0  Government expenditure on primary education, U...  Ukraine  2016
# 1  Government expenditure on primary education, U...  Ukraine  2017
# 2  Government expenditure on primary education, U...  Ukraine  2018
# 3  Government expenditure on primary education, U...  Ukraine  2019
# 4  Government expenditure on primary education, U...  Ukraine  2020
#
#         Value
# 0   918.52605
# 1  1316.29536
# 2  1595.33465
# 3  1857.26113
# 4  1840.77852

# %%
#Renaming Time column to year and making all column names lowercase
clean_gov_edu_expend_df.rename(columns={'Time':'year'}, inplace=True)
clean_gov_edu_expend_df.columns = clean_gov_edu_expend_df.columns.str.lower()
clean_gov_edu_expend_df.columns
# Out:
# Index(['indicator', 'country', 'year', 'value'], dtype='object')

# %%
#Reordering columns to make country and year the first two columns
clean_gov_edu_expend_df = clean_gov_edu_expend_df.reindex(columns = ['country', 'year','indicator','value'])
clean_gov_edu_expend_df.head()
# Out:
#    country  year                                          indicator  \
# 0  Ukraine  2016  Government expenditure on primary education, U...
# 1  Ukraine  2017  Government expenditure on primary education, U...
# 2  Ukraine  2018  Government expenditure on primary education, U...
# 3  Ukraine  2019  Government expenditure on primary education, U...
# 4  Ukraine  2020  Government expenditure on primary education, U...
#
#         value
# 0   918.52605
# 1  1316.29536
# 2  1595.33465
# 3  1857.26113
# 4  1840.77852

# %%
#Will be looking only be looking at the countries who have full data for years 2016-2019
clean_gov_edu_expend_df['year'].value_counts()
# Out:
# 2016    528
# 2017    486
# 2019    481
# 2018    454
# 2020    189
# 2021     83
# Name: year, dtype: int64

# %%
#Removing all rows for years 2020 and 2021
clean_gov_edu_expend_df = clean_gov_edu_expend_df[clean_gov_edu_expend_df['year'] < 2020]
clean_gov_edu_expend_df['year'].value_counts()
# Out:
# 2016    528
# 2017    486
# 2019    481
# 2018    454
# Name: year, dtype: int64

# %%
#Getting number of unique countries in dataset
len(clean_gov_edu_expend_df['country'].unique())
# Out:
# 123

# %%
#Countries with a value count of 24 should have data in all 6 indicators for all four years
clean_gov_edu_expend_df['country'].value_counts()
# Out:
# Ukraine                                                 24
# Netherlands                                             24
# Argentina                                               24
# Norway                                                  24
# Denmark                                                 24
# United States of America                                24
# Hungary                                                 24
# Estonia                                                 24
# Chile                                                   24
# Uruguay                                                 24
# Iran (Islamic Republic of)                              24
# Greece                                                  24
# Iceland                                                 24
# India                                                   24
# Andorra                                                 24
# Sierra Leone                                            24
# Belgium                                                 24
# Czechia                                                 24
# Lithuania                                               24
# Jamaica                                                 24
# Republic of Korea                                       24
# Guatemala                                               24
# Costa Rica                                              24
# Republic of Moldova                                     24
# Poland                                                  24
# Latvia                                                  24
# United Kingdom of Great Britain and Northern Ireland    24
# Romania                                                 24
# Colombia                                                24
# South Africa                                            24
# Türkiye                                                 24
# Finland                                                 24
# El Salvador                                             24
# Brazil                                                  24
# Slovenia                                                24
# Jordan                                                  24
# Holy See                                                24
# Mexico                                                  24
# Spain                                                   24
# Belize                                                  24
# Slovakia                                                24
# Ireland                                                 24
# Sweden                                                  24
# New Zealand                                             24
# Germany                                                 24
# Australia                                               24
# Austria                                                 24
# Dominican Republic                                      24
# Japan                                                   24
# Sri Lanka                                               24
# Italy                                                   22
# Saint Lucia                                             20
# Ecuador                                                 18
# Guinea                                                  18
# Côte d'Ivoire                                           18
# Bulgaria                                                18
# Cyprus                                                  18
# Maldives                                                18
# Switzerland                                             18
# San Marino                                              18
# France                                                  18
# Luxembourg                                              18
# Malta                                                   18
# Cabo Verde                                              18
# Myanmar                                                 18
# Niger                                                   18
# Portugal                                                18
# Oman                                                    16
# Kazakhstan                                              16
# Albania                                                 16
# Mongolia                                                14
# Rwanda                                                  12
# Mali                                                    12
# China, Hong Kong Special Administrative Region          12
# Monaco                                                  12
# Egypt                                                   12
# Mauritius                                               12
# Namibia                                                 12
# Senegal                                                 12
# Afghanistan                                             12
# Croatia                                                 12
# Zambia                                                  12
# Armenia                                                 12
# Israel                                                  10
# South Sudan                                              9
# Singapore                                                8
# Bangladesh                                               8
# Vanuatu                                                  8
# Montserrat                                               8
# Saint Vincent and the Grenadines                         8
# Turks and Caicos Islands                                 8
# Peru                                                     8
# Canada                                                   8
# Malaysia                                                 8
# Bosnia and Herzegovina                                   8
# Marshall Islands                                         6
# Barbados                                                 6
# Samoa                                                    6
# Azerbaijan                                               6
# Djibouti                                                 6
# Dominica                                                 6
# Paraguay                                                 6
# Malawi                                                   6
# Seychelles                                               6
# Togo                                                     6
# Brunei Darussalam                                        6
# Liberia                                                  6
# United Arab Emirates                                     6
# Bermuda                                                  6
# Chad                                                     6
# Bhutan                                                   4
# Nepal                                                    4
# Burkina Faso                                             4
# Lao People's Democratic Republic                         4
# Philippines                                              4
# Mauritania                                               4
# Timor-Leste                                              4
# British Virgin Islands                                   3
# Cambodia                                                 3
# Grenada                                                  2
# Lesotho                                                  2
# Aruba                                                    2
# Uzbekistan                                               2
# Name: country, dtype: int64

# %%
#Creating an index of all the countries that have a value count of 24
countries = clean_gov_edu_expend_df['country'].value_counts()[clean_gov_edu_expend_df['country'].value_counts() == 24].index
countries
# Out:
# Index(['Ukraine', 'Netherlands', 'Argentina', 'Norway', 'Denmark',
#        'United States of America', 'Hungary', 'Estonia', 'Chile', 'Uruguay',
#        'Iran (Islamic Republic of)', 'Greece', 'Iceland', 'India', 'Andorra',
#        'Sierra Leone', 'Belgium', 'Czechia', 'Lithuania', 'Jamaica',
#        'Republic of Korea', 'Guatemala', 'Costa Rica', 'Republic of Moldova',
#        'Poland', 'Latvia',
#        'United Kingdom of Great Britain and Northern Ireland', 'Romania',
#        'Colombia', 'South Africa', 'Türkiye', 'Finland', 'El Salvador',
#        'Brazil', 'Slovenia', 'Jordan', 'Holy See', 'Mexico', 'Spain', 'Belize',
#        'Slovakia', 'Ireland', 'Sweden', 'New Zealand', 'Germany', 'Australia',
#        'Austria', 'Dominican Republic', 'Japan', 'Sri Lanka'],
#       dtype='object')

# %%
#Removing countries that do not have all values for targeted years
clean_gov_edu_expend_df = clean_gov_edu_expend_df[clean_gov_edu_expend_df['country'].isin(countries)]
clean_gov_edu_expend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 2165
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1200 non-null   object
#  1   year       1200 non-null   int64
#  2   indicator  1200 non-null   object
#  3   value      1176 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 46.9+ KB

# %%
#Checking to see which countries have the NaN values
clean_gov_edu_expend_df[clean_gov_edu_expend_df['value'].isna() == True]['country'].unique()
# Out:
# array(['Holy See', 'Vanuatu', 'Montserrat', 'Namibia'], dtype=object)

# %%
#Dropping Holy See rows from the dataset
clean_gov_edu_expend_df.dropna(inplace=True)
clean_gov_edu_expend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 0 to 2165
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1176 non-null   object
#  1   year       1176 non-null   int64
#  2   indicator  1176 non-null   object
#  3   value      1176 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 45.9+ KB

# %%
#Number of unique countries now in the dataset
len(clean_gov_edu_expend_df['country'].unique())
# Out:
# 49

# %%
#Taking a look at the shape of the gdp dataset
gdp_df.shape
# Out:
# (3620, 9)

# %%
#Taking a look at the details
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3620 entries, 0 to 3619
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DEMO_IND    3620 non-null   object
#  1   Indicator   3620 non-null   object
#  2   LOCATION    3620 non-null   object
#  3   Country     3620 non-null   object
#  4   TIME        3620 non-null   int64
#  5   Time        3620 non-null   int64
#  6   Value       3617 non-null   float64
#  7   Flag Codes  3 non-null      object
#  8   Flags       3 non-null      object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 254.7+ KB

# %%
#Dropping unneeded columns
clean_gdp_df = gdp_df.copy()
clean_gdp_df = clean_gdp_df.drop(columns=["DEMO_IND", "LOCATION", "TIME", "Flag Codes","Flags"])
clean_gdp_df.head()
# Out:
#            Indicator    Country  Time         Value
# 0  GDP (current US$)  Australia  2016  1.206690e+12
# 1  GDP (current US$)  Australia  2017  1.326880e+12
# 2  GDP (current US$)  Australia  2018  1.428530e+12
# 3  GDP (current US$)  Australia  2019  1.391950e+12
# 4  GDP (current US$)  Australia  2020  1.327840e+12

# %%
#Renaming Time column to year and making all column names lowercase
clean_gdp_df.rename(columns={'Time':'year'}, inplace=True)
clean_gdp_df.columns = clean_gdp_df.columns.str.lower()
clean_gdp_df.columns
# Out:
# Index(['indicator', 'country', 'year', 'value'], dtype='object')

# %%
#Reordering columns
clean_gdp_df = clean_gdp_df.reindex(columns=['country','year', 'indicator', 'value'])
clean_gdp_df.head()
# Out:
#      country  year          indicator         value
# 0  Australia  2016  GDP (current US$)  1.206690e+12
# 1  Australia  2017  GDP (current US$)  1.326880e+12
# 2  Australia  2018  GDP (current US$)  1.428530e+12
# 3  Australia  2019  GDP (current US$)  1.391950e+12
# 4  Australia  2020  GDP (current US$)  1.327840e+12

# %%
#Getting year value counts
clean_gdp_df['year'].value_counts()
# Out:
# 2016    621
# 2017    621
# 2018    621
# 2019    615
# 2020    603
# 2021    539
# Name: year, dtype: int64

# %%
#Removing years that will not be targeted in order to match the clean_gov_edu_expend_df dataframe
clean_gdp_df = clean_gdp_df[clean_gdp_df['year'] < 2020]
clean_gdp_df['year'].value_counts()
# Out:
# 2016    621
# 2017    621
# 2018    621
# 2019    615
# Name: year, dtype: int64

# %%
#Getting number of unique countries in dataframe
len(clean_gdp_df['country'].unique())
# Out:
# 208

# %%
#Countries with a value count of 12 should have data in all 3 indicators for all four years
clean_gdp_df['country'].value_counts()
# Out:
# Australia                                               12
# Romania                                                 12
# Niger                                                   12
# Nigeria                                                 12
# Oman                                                    12
# Pakistan                                                12
# Palau                                                   12
# Panama                                                  12
# Papua New Guinea                                        12
# Paraguay                                                12
# Peru                                                    12
# Puerto Rico                                             12
# Russian Federation                                      12
# Nepal                                                   12
# Rwanda                                                  12
# Saint Vincent and the Grenadines                        12
# Samoa                                                   12
# San Marino                                              12
# Saudi Arabia                                            12
# Seychelles                                              12
# Sierra Leone                                            12
# Singapore                                               12
# Solomon Islands                                         12
# Sudan                                                   12
# Nicaragua                                               12
# Namibia                                                 12
# Kuwait                                                  12
# Malaysia                                                12
# Austria                                                 12
# Latvia                                                  12
# Lebanon                                                 12
# Lesotho                                                 12
# Liberia                                                 12
# Libya                                                   12
# Lithuania                                               12
# North Macedonia                                         12
# Madagascar                                              12
# Malawi                                                  12
# Maldives                                                12
# Mozambique                                              12
# Mali                                                    12
# Malta                                                   12
# Marshall Islands                                        12
# Mauritania                                              12
# Mauritius                                               12
# Micronesia (Federated States of)                        12
# Republic of Moldova                                     12
# Monaco                                                  12
# Mongolia                                                12
# Morocco                                                 12
# Timor-Leste                                             12
# Togo                                                    12
# Uruguay                                                 12
# Tunisia                                                 12
# Saint Kitts and Nevis                                   12
# Sweden                                                  12
# Belarus                                                 12
# United Arab Emirates                                    12
# Thailand                                                12
# Sao Tome and Principe                                   12
# Isle of Man                                             12
# Tuvalu                                                  12
# Switzerland                                             12
# Somalia                                                 12
# United States of America                                12
# Uzbekistan                                              12
# Eswatini                                                12
# Spain                                                   12
# Saint Lucia                                             12
# Tajikistan                                              12
# Palestine                                               12
# Nauru                                                   12
# American Samoa                                          12
# Guam                                                    12
# Northern Mariana Islands                                12
# Curaçao                                                 12
# Tonga                                                   12
# Türkiye                                                 12
# Philippines                                             12
# Turkmenistan                                            12
# Vanuatu                                                 12
# United States Virgin Islands                            12
# Yemen                                                   12
# Zambia                                                  12
# Zimbabwe                                                12
# China, Macao Special Administrative Region              12
# Serbia                                                  12
# Montenegro                                              12
# Myanmar                                                 12
# Ukraine                                                 12
# Suriname                                                12
# United Republic of Tanzania                             12
# Sri Lanka                                               12
# United Kingdom of Great Britain and Northern Ireland    12
# South Africa                                            12
# Qatar                                                   12
# Uganda                                                  12
# Slovenia                                                12
# Senegal                                                 12
# Trinidad and Tobago                                     12
# Viet Nam                                                12
# Kyrgyzstan                                              12
# Lao People's Democratic Republic                        12
# Kiribati                                                12
# Kenya                                                   12
# Angola                                                  12
# Antigua and Barbuda                                     12
# Argentina                                               12
# Armenia                                                 12
# Aruba                                                   12
# Azerbaijan                                              12
# Bahamas                                                 12
# Bahrain                                                 12
# Bangladesh                                              12
# Barbados                                                12
# Belize                                                  12
# Benin                                                   12
# Bermuda                                                 12
# Bhutan                                                  12
# Bolivia (Plurinational State of)                        12
# Bosnia and Herzegovina                                  12
# Botswana                                                12
# Brazil                                                  12
# Brunei Darussalam                                       12
# Bulgaria                                                12
# Burkina Faso                                            12
# Burundi                                                 12
# Cambodia                                                12
# Andorra                                                 12
# Algeria                                                 12
# Albania                                                 12
# Ireland                                                 12
# Belgium                                                 12
# Canada                                                  12
# Czechia                                                 12
# Denmark                                                 12
# Finland                                                 12
# France                                                  12
# Germany                                                 12
# Greece                                                  12
# Hungary                                                 12
# Iceland                                                 12
# Italy                                                   12
# Afghanistan                                             12
# Japan                                                   12
# Republic of Korea                                       12
# Luxembourg                                              12
# Mexico                                                  12
# Netherlands                                             12
# New Zealand                                             12
# Norway                                                  12
# Poland                                                  12
# Portugal                                                12
# Slovakia                                                12
# Cameroon                                                12
# Cabo Verde                                              12
# Fiji                                                    12
# Cayman Islands                                          12
# Gabon                                                   12
# Gambia                                                  12
# Georgia                                                 12
# Ghana                                                   12
# Greenland                                               12
# Grenada                                                 12
# Guatemala                                               12
# Guinea                                                  12
# Guinea-Bissau                                           12
# Guyana                                                  12
# Haiti                                                   12
# Honduras                                                12
# China, Hong Kong Special Administrative Region          12
# India                                                   12
# Indonesia                                               12
# Iran (Islamic Republic of)                              12
# Iraq                                                    12
# Israel                                                  12
# Jamaica                                                 12
# Jordan                                                  12
# Kazakhstan                                              12
# French Polynesia                                        12
# Turks and Caicos Islands                                12
# Cuba                                                    12
# Chad                                                    12
# China                                                   12
# Colombia                                                12
# Comoros                                                 12
# Congo                                                   12
# Costa Rica                                              12
# Côte d'Ivoire                                           12
# Croatia                                                 12
# Central African Republic                                12
# Cyprus                                                  12
# Democratic Republic of the Congo                        12
# Djibouti                                                12
# Dominica                                                12
# Dominican Republic                                      12
# Ecuador                                                 12
# Egypt                                                   12
# El Salvador                                             12
# Equatorial Guinea                                       12
# Estonia                                                 12
# Ethiopia                                                12
# Chile                                                   12
# Sint Maarten (Dutch part)                                9
# Syrian Arab Republic                                     9
# Liechtenstein                                            8
# New Caledonia                                            8
# Faeroe Islands                                           8
# Name: country, dtype: int64

# %%
#Creating an index of all the countries that have a value count of 12
countries = clean_gdp_df['country'].value_counts()[clean_gdp_df['country'].value_counts() == 12].index
countries
# Out:
# Index(['Australia', 'Romania', 'Niger', 'Nigeria', 'Oman', 'Pakistan', 'Palau',
#        'Panama', 'Papua New Guinea', 'Paraguay',
#        ...
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Estonia', 'Ethiopia', 'Chile'],
#       dtype='object', length=203)

# %%
# Removing countries with a value count of less than 12
clean_gdp_df = clean_gdp_df[clean_gdp_df['country'].isin(countries)]
clean_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 3611
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    2436 non-null   object
#  1   year       2436 non-null   int64
#  2   indicator  2436 non-null   object
#  3   value      2433 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 95.2+ KB

# %%
#Creating a set from the countries in the clean_gov_edu_expend_df dataframe
gov_edu_countries = set(clean_gov_edu_expend_df['country'].unique())
gov_edu_countries
# Out:
# {'Andorra',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Belize',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Czechia',
#  'Denmark',
#  'Dominican Republic',
#  'El Salvador',
#  'Estonia',
#  'Finland',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Iran (Islamic Republic of)',
#  'Ireland',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Latvia',
#  'Lithuania',
#  'Mexico',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Poland',
#  'Republic of Korea',
#  'Republic of Moldova',
#  'Romania',
#  'Sierra Leone',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Türkiye',
#  'Ukraine',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America',
#  'Uruguay'}

# %%
#Removing any countries not in the clean_gov_edu_expend_df dataframe
clean_gdp_df = clean_gdp_df[clean_gdp_df['country'].isin(gov_edu_countries)]
clean_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588 entries, 0 to 3485
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    588 non-null    object
#  1   year       588 non-null    int64
#  2   indicator  588 non-null    object
#  3   value      588 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 23.0+ KB

# %%
#Set test to make sure there are no differences in countries between both data frames
gdp_countries = set(clean_gdp_df['country'].unique())
gdp_countries.difference(gov_edu_countries)
# Out:
# set()

# %%
internet_df.shape
# Out:
# (271, 10)

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    268 non-null    object
#  1   Series Code    266 non-null    object
#  2   Country Name   266 non-null    object
#  3   Country Code   266 non-null    object
#  4   1990 [YR1990]  266 non-null    object
#  5   2012 [YR2012]  266 non-null    object
#  6   2016 [YR2016]  266 non-null    object
#  7   2017 [YR2017]  266 non-null    object
#  8   2018 [YR2018]  266 non-null    object
#  9   2019 [YR2019]  266 non-null    object
# dtypes: object(10)
# memory usage: 21.3+ KB

# %%
#Dropping unneeded columns
clean_internet_df = internet_df.copy()
clean_internet_df = internet_df.drop(columns=['Series Code', 'Country Code', '1990 [YR1990]', '2012 [YR2012]'])
clean_internet_df.head()
# Out:
#                                         Series Name    Country Name  \
# 0  Individuals using the Internet (% of population)     Afghanistan
# 1  Individuals using the Internet (% of population)         Albania
# 2  Individuals using the Internet (% of population)         Algeria
# 3  Individuals using the Internet (% of population)  American Samoa
# 4  Individuals using the Internet (% of population)         Andorra
#
#   2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0            11          13.5          16.8          17.6
# 1          59.6          62.4          65.4   68.55039112
# 2   42.94552688   47.69105515   49.03846808          57.9
# 3            ..            ..            ..            ..
# 4          89.7   91.56746703            ..            ..

# %%
#Renaming all column names
columns = ['indicator', 'country', '2016', '2017', '2018', '2019']
clean_internet_df.columns = columns
clean_internet_df.columns
# Out:
# Index(['indicator', 'country', '2016', '2017', '2018', '2019'], dtype='object')

# %%
#Melt the year columns into one column called "year"
clean_internet_df = pd.melt(clean_internet_df,id_vars=['country', 'indicator'],value_vars=['2016','2017','2018','2019'], var_name='year')
clean_internet_df.head()
# Out:
#           country                                         indicator  year  \
# 0     Afghanistan  Individuals using the Internet (% of population)  2016
# 1         Albania  Individuals using the Internet (% of population)  2016
# 2         Algeria  Individuals using the Internet (% of population)  2016
# 3  American Samoa  Individuals using the Internet (% of population)  2016
# 4         Andorra  Individuals using the Internet (% of population)  2016
#
#          value
# 0           11
# 1         59.6
# 2  42.94552688
# 3           ..
# 4         89.7

# %%
#Rearrange column order to make "country" and "year" column first
clean_internet_df = clean_internet_df.reindex(columns=['country','year','indicator','value'])
clean_internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1064 non-null   object
#  1   year       1084 non-null   object
#  2   indicator  1072 non-null   object
#  3   value      1064 non-null   object
# dtypes: object(4)
# memory usage: 34.0+ KB

# %%
#Removing .. values
clean_internet_df = clean_internet_df[clean_internet_df['value'] !='..']
clean_internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 0 to 1083
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    916 non-null    object
#  1   year       936 non-null    object
#  2   indicator  924 non-null    object
#  3   value      916 non-null    object
# dtypes: object(4)
# memory usage: 36.6+ KB

# %%
#Countries with a value count of 4 should have data in the indicator for all four years
clean_internet_df['country'].value_counts()
# Out:
# Afghanistan                                             4
# Romania                                                 4
# Rwanda                                                  4
# Sao Tome and Principe                                   4
# Saudi Arabia                                            4
# Senegal                                                 4
# Serbia                                                  4
# Seychelles                                              4
# Sierra Leone                                            4
# Singapore                                               4
# Slovak Republic                                         4
# Slovenia                                                4
# South Africa                                            4
# South Sudan                                             4
# Spain                                                   4
# Sri Lanka                                               4
# St. Lucia                                               4
# Sudan                                                   4
# Suriname                                                4
# Sweden                                                  4
# Switzerland                                             4
# Syrian Arab Republic                                    4
# Tanzania                                                4
# Thailand                                                4
# Timor-Leste                                             4
# Togo                                                    4
# Tunisia                                                 4
# Russian Federation                                      4
# Qatar                                                   4
# Uganda                                                  4
# Puerto Rico                                             4
# Malta                                                   4
# Mauritania                                              4
# Mauritius                                               4
# Mexico                                                  4
# Mongolia                                                4
# Montenegro                                              4
# Albania                                                 4
# Mozambique                                              4
# Myanmar                                                 4
# Namibia                                                 4
# Nepal                                                   4
# Netherlands                                             4
# New Zealand                                             4
# Nicaragua                                               4
# Nigeria                                                 4
# North Macedonia                                         4
# Norway                                                  4
# Oman                                                    4
# Pakistan                                                4
# Panama                                                  4
# Paraguay                                                4
# Peru                                                    4
# Philippines                                             4
# Poland                                                  4
# Portugal                                                4
# Turkiye                                                 4
# Ukraine                                                 4
# Maldives                                                4
# IDA only                                                4
# Late-demographic dividend                               4
# Latin America & Caribbean                               4
# Latin America & Caribbean (excluding high income)       4
# Latin America & the Caribbean (IDA & IBRD countries)    4
# Least developed countries: UN classification            4
# Low & middle income                                     4
# Low income                                              4
# Lower middle income                                     4
# Middle East & North Africa                              4
# Middle East & North Africa (excluding high income)      4
# Middle East & North Africa (IDA & IBRD countries)       4
# Middle income                                           4
# North America                                           4
# OECD members                                            4
# Other small states                                      4
# Post-demographic dividend                               4
# Pre-demographic dividend                                4
# Small states                                            4
# South Asia                                              4
# South Asia (IDA & IBRD)                                 4
# Sub-Saharan Africa                                      4
# Sub-Saharan Africa (excluding high income)              4
# Sub-Saharan Africa (IDA & IBRD countries)               4
# Upper middle income                                     4
# World                                                   4
# IDA total                                               4
# IDA blend                                               4
# United Arab Emirates                                    4
# IDA & IBRD total                                        4
# United Kingdom                                          4
# United States                                           4
# Uruguay                                                 4
# Uzbekistan                                              4
# Vietnam                                                 4
# West Bank and Gaza                                      4
# Zambia                                                  4
# Zimbabwe                                                4
# Africa Eastern and Southern                             4
# Africa Western and Central                              4
# Arab World                                              4
# Central Europe and the Baltics                          4
# Early-demographic dividend                              4
# East Asia & Pacific                                     4
# East Asia & Pacific (excluding high income)             4
# East Asia & Pacific (IDA & IBRD countries)              4
# Euro area                                               4
# Europe & Central Asia                                   4
# Europe & Central Asia (excluding high income)           4
# Europe & Central Asia (IDA & IBRD countries)            4
# European Union                                          4
# Fragile and conflict affected situations                4
# Heavily indebted poor countries (HIPC)                  4
# High income                                             4
# IBRD only                                               4
# Mali                                                    4
# Morocco                                                 4
# Malaysia                                                4
# Belgium                                                 4
# Botswana                                                4
# Bosnia and Herzegovina                                  4
# Bolivia                                                 4
# Malawi                                                  4
# Estonia                                                 4
# Bhutan                                                  4
# Benin                                                   4
# Ethiopia                                                4
# Belize                                                  4
# Finland                                                 4
# Egypt, Arab Rep.                                        4
# France                                                  4
# Belarus                                                 4
# Gabon                                                   4
# Gambia, The                                             4
# Georgia                                                 4
# Germany                                                 4
# Ghana                                                   4
# Canada                                                  4
# Greece                                                  4
# El Salvador                                             4
# Ecuador                                                 4
# Bahamas, The                                            4
# Croatia                                                 4
# Chad                                                    4
# Chile                                                   4
# China                                                   4
# Colombia                                                4
# Cameroon                                                4
# Congo, Dem. Rep.                                        4
# Costa Rica                                              4
# Cabo Verde                                              4
# Cote d'Ivoire                                           4
# Cuba                                                    4
# Dominican Republic                                      4
# Burundi                                                 4
# Cyprus                                                  4
# Burkina Faso                                            4
# Czechia                                                 4
# Bulgaria                                                4
# Denmark                                                 4
# Brunei Darussalam                                       4
# Djibouti                                                4
# Brazil                                                  4
# Bahrain                                                 4
# Bangladesh                                              4
# Japan                                                   4
# Israel                                                  4
# Grenada                                                 4
# Kazakhstan                                              4
# Kenya                                                   4
# Kiribati                                                4
# Armenia                                                 4
# Korea, Rep.                                             4
# Kuwait                                                  4
# Kyrgyz Republic                                         4
# Lao PDR                                                 4
# Latvia                                                  4
# Lebanon                                                 4
# Lesotho                                                 4
# Liberia                                                 4
# Argentina                                               4
# Lithuania                                               4
# Angola                                                  4
# Algeria                                                 4
# Luxembourg                                              4
# Macao SAR, China                                        4
# Italy                                                   4
# Central African Republic                                4
# Ireland                                                 4
# Hungary                                                 4
# Azerbaijan                                              4
# Guatemala                                               4
# Guinea                                                  4
# Guinea-Bissau                                           4
# Austria                                                 4
# Haiti                                                   4
# Honduras                                                4
# Hong Kong SAR, China                                    4
# Australia                                               4
# India                                                   4
# Indonesia                                               4
# Iran, Islamic Rep.                                      4
# Iceland                                                 4
# Iraq                                                    4
# Fiji                                                    3
# Jordan                                                  3
# Madagascar                                              3
# Jamaica                                                 3
# St. Vincent and the Grenadines                          3
# Kosovo                                                  2
# Barbados                                                2
# Andorra                                                 2
# Cambodia                                                2
# Bermuda                                                 2
# British Virgin Islands                                  2
# Aruba                                                   2
# Pacific island small states                             2
# Eritrea                                                 2
# Cayman Islands                                          2
# Samoa                                                   2
# Comoros                                                 2
# Somalia                                                 2
# Solomon Islands                                         2
# Greenland                                               2
# Guam                                                    2
# Guyana                                                  2
# Papua New Guinea                                        2
# Tajikistan                                              2
# Niger                                                   2
# Liechtenstein                                           2
# Monaco                                                  2
# Moldova                                                 2
# Micronesia, Fed. Sts.                                   2
# Marshall Islands                                        2
# French Polynesia                                        2
# St. Kitts and Nevis                                     2
# Faroe Islands                                           2
# Vanuatu                                                 2
# Congo, Rep.                                             2
# Caribbean small states                                  2
# Curacao                                                 2
# Yemen, Rep.                                             2
# Virgin Islands (U.S.)                                   2
# Eswatini                                                2
# Venezuela, RB                                           2
# Dominica                                                2
# Equatorial Guinea                                       2
# Tuvalu                                                  2
# Turkmenistan                                            2
# Trinidad and Tobago                                     2
# Tonga                                                   2
# Antigua and Barbuda                                     1
# Gibraltar                                               1
# Nauru                                                   1
# New Caledonia                                           1
# San Marino                                              1
# Name: country, dtype: int64

# %%
#Saving the countries with a value count of less than 4 for later 
countries_less_than_four = clean_internet_df['country'].value_counts()[clean_internet_df['country'].value_counts() < 4].index

#Creating an index of all the countries that have a value count of 4
countries = clean_internet_df['country'].value_counts()[clean_internet_df['country'].value_counts() == 4].index

#Removing countries that do not have all values for targeted years
clean_internet_df = clean_internet_df[clean_internet_df['country'].isin(countries)]
clean_internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 812 entries, 0 to 1078
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    812 non-null    object
#  1   year       812 non-null    object
#  2   indicator  812 non-null    object
#  3   value      812 non-null    object
# dtypes: object(4)
# memory usage: 31.7+ KB

# %%
#Creating set from countries in clean_internet_df dataframe
internet_countries = set(clean_internet_df['country'].unique())

#Checking for differences between countries in clean_gov_edu_expend_df
country_diff = gov_edu_countries.symmetric_difference(internet_countries)
country_diff_list = list(country_diff)

#Determining which countries are not in internet df
check_diff = [country for country in country_diff_list if country not in internet_countries]
check_diff
# Out:
# ['Türkiye',
#  'Republic of Moldova',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Slovakia',
#  'Andorra',
#  'Jamaica',
#  'Jordan',
#  'United States of America',
#  'Republic of Korea',
#  'Iran (Islamic Republic of)']

# %%
#Checking to see which countries in country_diff are not in less_than_four_countries
#Will check to see if these are false postivites
set(check_diff).difference(set(countries_less_than_four))
# Out:
# {'Iran (Islamic Republic of)',
#  'Republic of Korea',
#  'Republic of Moldova',
#  'Slovakia',
#  'Türkiye',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'United States of America'}

# %%
#Checking for false positives
#Checking for Iran
clean_internet_df[clean_internet_df['country'].str.find('Iran') > -1]
# Out:
#                 country  year  \
# 91   Iran, Islamic Rep.  2016
# 362  Iran, Islamic Rep.  2017
# 633  Iran, Islamic Rep.  2018
# 904  Iran, Islamic Rep.  2019
#
#                                             indicator        value
# 91   Individuals using the Internet (% of population)  53.22677167
# 362  Individuals using the Internet (% of population)  64.04397362
# 633  Individuals using the Internet (% of population)    70.200565
# 904  Individuals using the Internet (% of population)  77.77083846

# %%
#Checking for Korea
clean_internet_df[clean_internet_df['country'].str.find('Korea') > -1]
# Out:
#          country  year                                         indicator  \
# 104  Korea, Rep.  2016  Individuals using the Internet (% of population)
# 375  Korea, Rep.  2017  Individuals using the Internet (% of population)
# 646  Korea, Rep.  2018  Individuals using the Internet (% of population)
# 917  Korea, Rep.  2019  Individuals using the Internet (% of population)
#
#            value
# 104  92.84302568
# 375  95.06942188
# 646  96.02285958
# 917  96.15757918

# %%
#Checking for Moldova
clean_internet_df[clean_internet_df['country'].str.find('Mold') > -1]
# Out:
# Empty DataFrame
# Columns: [country, year, indicator, value]
# Index: []

# %%
#Checking for Slovakia
clean_internet_df[clean_internet_df['country'].str.find('Slova') > -1]
# Out:
#              country  year                                         indicator  \
# 173  Slovak Republic  2016  Individuals using the Internet (% of population)
# 444  Slovak Republic  2017  Individuals using the Internet (% of population)
# 715  Slovak Republic  2018  Individuals using the Internet (% of population)
# 986  Slovak Republic  2019  Individuals using the Internet (% of population)
#
#            value
# 173  80.47585728
# 444  81.62566752
# 715  80.44892248
# 986   82.8536605

# %%
#Checking for Türkiye
clean_internet_df[clean_internet_df['country'].str.find('Turk') > -1]
# Out:
#       country  year                                         indicator  \
# 198   Turkiye  2016  Individuals using the Internet (% of population)
# 469   Turkiye  2017  Individuals using the Internet (% of population)
# 740   Turkiye  2018  Individuals using the Internet (% of population)
# 1011  Turkiye  2019  Individuals using the Internet (% of population)
#
#             value
# 198   58.34773401
# 469   64.68461768
# 740   71.04276084
# 1011  73.97670281

# %%
#Checking for United Kingdom of Great Britain and Northern Ireland
clean_internet_df[clean_internet_df['country'].str.find('King') > -1]
# Out:
#              country  year                                         indicator  \
# 205   United Kingdom  2016  Individuals using the Internet (% of population)
# 476   United Kingdom  2017  Individuals using the Internet (% of population)
# 747   United Kingdom  2018  Individuals using the Internet (% of population)
# 1018  United Kingdom  2019  Individuals using the Internet (% of population)
#
#             value
# 205   94.77580063
# 476   90.42455049
# 747   90.69200899
# 1018  92.51662855

# %%
#Checking for United States of America
clean_internet_df[clean_internet_df['country'].str.find('States') > -1]
# Out:
#             country  year                                         indicator  \
# 206   United States  2016  Individuals using the Internet (% of population)
# 477   United States  2017  Individuals using the Internet (% of population)
# 748   United States  2018  Individuals using the Internet (% of population)
# 1019  United States  2019  Individuals using the Internet (% of population)
#
#             value
# 206   85.54442129
# 477   87.27488917
# 748   88.49890317
# 1019  89.43028486

# %%
#Making a dictionary for replacements
country_dict = {'Iran, Islamic Rep.':'Iran (Islamic Republic of)', 'Korea, Rep.':'Republic of Korea',
                'Slovak Republic':'Slovakia', 'Turkiye':'Türkiye', 'United Kingdom':'United Kingdom of Great Britain and Northern Ireland',
                'United States':'United States of America'}

#Making replacements for in country column 
clean_internet_df.replace({'country':country_dict},inplace=True)

#Comparing differences in countries in the internet and gov_edu_expend dataframes
internet_countries = set(clean_internet_df['country'].unique())
country_diff = gov_edu_countries.difference(internet_countries)

#These will need to be removed from the gov_edu_expend and gdp dataframes
country_diff
# Out:
# {'Andorra', 'Jamaica', 'Jordan', 'Republic of Moldova'}

# %%
#Removing countries in country_diff from the gov_edu_expend and gdp dataframes
clean_gov_edu_expend_df = clean_gov_edu_expend_df[clean_gov_edu_expend_df['country'].isin(country_diff) == False]
clean_gdp_df = clean_gdp_df[clean_gdp_df['country'].isin(country_diff) == False]

#Comparing differences in countries in the internet and gov_edu_expend dataframes
gov_edu_countries = set(clean_gov_edu_expend_df['country'].unique())
country_diff = gov_edu_countries.symmetric_difference(internet_countries)

#Removing countries in country_diff from internet df
clean_internet_df = clean_internet_df[clean_internet_df['country'].isin(country_diff) == False]

#Comparing differences in countries in the internet and gov_edu_expend dataframes
internet_countries = set(clean_internet_df['country'].unique())
country_diff = gov_edu_countries.symmetric_difference(internet_countries)

print(country_diff, len(clean_gov_edu_expend_df['country'].unique()), len(clean_gdp_df['country'].unique()), len(clean_internet_df['country'].unique()))
# Out:
# set() 45 45 45

# %%
#Convert year column to int
clean_internet_df.loc[:, 'year'] = clean_internet_df['year'].astype("int64",errors='ignore')

#Converting value column  from object to float
clean_internet_df.loc[:, 'value'] = clean_internet_df['value'].astype("float",errors='ignore')
clean_internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 7 to 1020
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    180 non-null    object
#  1   year       180 non-null    int64
#  2   indicator  180 non-null    object
#  3   value      180 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.0+ KB
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
patents_force_df.shape
# Out:
# (135, 10)

# %%
patents_force_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  135 non-null    object
#  1   Unnamed: 1  134 non-null    object
#  2   Unnamed: 2  135 non-null    object
#  3   Unnamed: 3  135 non-null    object
#  4   2016        105 non-null    float64
#  5   2017        111 non-null    float64
#  6   2018        116 non-null    float64
#  7   2019        112 non-null    float64
#  8   2020        115 non-null    float64
#  9   2021        106 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 10.7+ KB

# %%
#Dropping the columns that are not needed
clean_patents_force_df = patents_force_df.copy()
clean_patents_force_df = clean_patents_force_df.drop(columns=['Unnamed: 1', 'Unnamed: 2', '2020', '2021'])

#Renaming columns
clean_patents_force_df.rename(columns={'Unnamed: 0':'country', 'Unnamed: 3':'indicator' }, inplace=True)

#Updating indicatior column values to make it clearer
clean_patents_force_df.loc[:, 'indicator'] = 'Grant of Patents (number)'
clean_patents_force_df.head()
# Out:
#                                              country  \
# 0                                             Office
# 1         African Intellectual Property Organization
# 2  African Regional Intellectual Property Organiz...
# 3                                            Albania
# 4                                            Algeria
#
#                    indicator    2016    2017    2018    2019
# 0  Grant of Patents (number)     NaN     NaN     NaN     NaN
# 1  Grant of Patents (number)  2220.0     NaN     NaN     NaN
# 2  Grant of Patents (number)  1770.0  1977.0  2007.0  1921.0
# 3  Grant of Patents (number)  1645.0  4946.0  5021.0  6017.0
# 4  Grant of Patents (number)  5618.0  2171.0  2084.0  4496.0

# %%
#Melt the year columns into one column called "year"
clean_patents_force_df = pd.melt(clean_patents_force_df,id_vars=['country', 'indicator'],value_vars=['2016','2017','2018','2019'], var_name='year')
clean_patents_force_df.head()
# Out:
#                                              country  \
# 0                                             Office
# 1         African Intellectual Property Organization
# 2  African Regional Intellectual Property Organiz...
# 3                                            Albania
# 4                                            Algeria
#
#                    indicator  year   value
# 0  Grant of Patents (number)  2016     NaN
# 1  Grant of Patents (number)  2016  2220.0
# 2  Grant of Patents (number)  2016  1770.0
# 3  Grant of Patents (number)  2016  1645.0
# 4  Grant of Patents (number)  2016  5618.0

# %%
clean_patents_force_df = clean_patents_force_df.reindex(columns=['country','year','indicator','value'])
clean_patents_force_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    540 non-null    object
#  1   year       540 non-null    object
#  2   indicator  540 non-null    object
#  3   value      444 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 17.0+ KB

# %%
len(clean_patents_force_df['country'].unique())
# Out:
# 135

# %%
#Countries with NaN values
clean_patents_force_df[clean_patents_force_df['value'].isna() == True]['country'].unique()
# Out:
# array(['Office', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Brunei Darussalam', 'Cabo Verde', 'Costa Rica',
#        'Democratic Republic of the Congo', 'Ecuador', 'Honduras',
#        'Indonesia', "Lao People's Democratic Republic", 'Mauritius',
#        'Morocco', 'Nigeria', 'North Macedonia', 'Papua New Guinea',
#        'Paraguay', 'Qatar', 'Rwanda', 'Saint Vincent and the Grenadines',
#        'Slovenia', 'Syrian Arab Republic', 'Trinidad and Tobago',
#        'Tuvalu', 'Uruguay', 'Venezuela (Bolivarian Republic of)', 'Yemen',
#        'Zimbabwe', 'African Intellectual Property Organization', 'Belize',
#        'Guyana', 'Mongolia', 'Uganda', 'Bahamas', 'Bhutan', 'Ghana',
#        'Kazakhstan', 'Tunisia', 'Gambia', 'Sudan'], dtype=object)

# %%
#Removing countries with NaN values from dataset
nan_countries = clean_patents_force_df[clean_patents_force_df['value'].isna() == True]['country'].unique()
clean_patents_force_df = clean_patents_force_df[clean_patents_force_df['country'].isin(nan_countries) == False]
clean_patents_force_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 2 to 538
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    372 non-null    object
#  1   year       372 non-null    object
#  2   indicator  372 non-null    object
#  3   value      372 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 14.5+ KB

# %%
clean_patents_force_df[clean_patents_force_df['value'].isna() == True]
# Out:
#                                         country  year  \
# 0                                        Office  2016
# 5                                       Andorra  2016
# 6                                        Angola  2016
# 7                           Antigua and Barbuda  2016
# 8                                     Argentina  2016
# 23                            Brunei Darussalam  2016
# 25                                   Cabo Verde  2016
# 32                                   Costa Rica  2016
# 37             Democratic Republic of the Congo  2016
# 40                                      Ecuador  2016
# 52                                     Honduras  2016
# 56                                    Indonesia  2016
# 67             Lao People's Democratic Republic  2016
# 74                                    Mauritius  2016
# 78                                      Morocco  2016
# 83                                      Nigeria  2016
# 84                              North Macedonia  2016
# 89                             Papua New Guinea  2016
# 90                                     Paraguay  2016
# 96                                        Qatar  2016
# 101                                      Rwanda  2016
# 102            Saint Vincent and the Grenadines  2016
# 110                                    Slovenia  2016
# 117                        Syrian Arab Republic  2016
# 119                         Trinidad and Tobago  2016
# 122                                      Tuvalu  2016
# 128                                     Uruguay  2016
# 130          Venezuela (Bolivarian Republic of)  2016
# 132                                       Yemen  2016
# 134                                    Zimbabwe  2016
# 135                                      Office  2017
# 136  African Intellectual Property Organization  2017
# 141                                      Angola  2017
# 142                         Antigua and Barbuda  2017
# 153                                      Belize  2017
# 160                                  Cabo Verde  2017
# 167                                  Costa Rica  2017
# 172            Democratic Republic of the Congo  2017
# 186                                      Guyana  2017
# 191                                   Indonesia  2017
# 202            Lao People's Democratic Republic  2017
# 212                                    Mongolia  2017
# 218                                     Nigeria  2017
# 219                             North Macedonia  2017
# 224                            Papua New Guinea  2017
# 225                                    Paraguay  2017
# 231                                       Qatar  2017
# 245                                    Slovenia  2017
# 254                         Trinidad and Tobago  2017
# 257                                      Tuvalu  2017
# 258                                      Uganda  2017
# 265          Venezuela (Bolivarian Republic of)  2017
# 267                                       Yemen  2017
# 269                                    Zimbabwe  2017
# 270                                      Office  2018
# 271  African Intellectual Property Organization  2018
# 276                                      Angola  2018
# 278                                   Argentina  2018
# 283                                     Bahamas  2018
# 289                                      Bhutan  2018
# 302                                  Costa Rica  2018
# 318                                       Ghana  2018
# 321                                      Guyana  2018
# 335                                  Kazakhstan  2018
# 337            Lao People's Democratic Republic  2018
# 354                             North Macedonia  2018
# 366                                       Qatar  2018
# 387                        Syrian Arab Republic  2018
# 389                         Trinidad and Tobago  2018
# 390                                     Tunisia  2018
# 393                                      Uganda  2018
# 398                                     Uruguay  2018
# 400          Venezuela (Bolivarian Republic of)  2018
# 405                                      Office  2019
# 406  African Intellectual Property Organization  2019
# 411                                      Angola  2019
# 412                         Antigua and Barbuda  2019
# 413                                   Argentina  2019
# 418                                     Bahamas  2019
# 430                                  Cabo Verde  2019
# 450                                      Gambia  2019
# 453                                       Ghana  2019
# 456                                      Guyana  2019
# 461                                   Indonesia  2019
# 472            Lao People's Democratic Republic  2019
# 479                                   Mauritius  2019
# 501                                       Qatar  2019
# 506                                      Rwanda  2019
# 515                                    Slovenia  2019
# 519                                       Sudan  2019
# 522                        Syrian Arab Republic  2019
# 524                         Trinidad and Tobago  2019
# 525                                     Tunisia  2019
# 528                                      Uganda  2019
# 533                                     Uruguay  2019
# 535          Venezuela (Bolivarian Republic of)  2019
#
#                      indicator  value
# 0    Grant of Patents (number)    NaN
# 5    Grant of Patents (number)    NaN
# 6    Grant of Patents (number)    NaN
# 7    Grant of Patents (number)    NaN
# 8    Grant of Patents (number)    NaN
# 23   Grant of Patents (number)    NaN
# 25   Grant of Patents (number)    NaN
# 32   Grant of Patents (number)    NaN
# 37   Grant of Patents (number)    NaN
# 40   Grant of Patents (number)    NaN
# 52   Grant of Patents (number)    NaN
# 56   Grant of Patents (number)    NaN
# 67   Grant of Patents (number)    NaN
# 74   Grant of Patents (number)    NaN
# 78   Grant of Patents (number)    NaN
# 83   Grant of Patents (number)    NaN
# 84   Grant of Patents (number)    NaN
# 89   Grant of Patents (number)    NaN
# 90   Grant of Patents (number)    NaN
# 96   Grant of Patents (number)    NaN
# 101  Grant of Patents (number)    NaN
# 102  Grant of Patents (number)    NaN
# 110  Grant of Patents (number)    NaN
# 117  Grant of Patents (number)    NaN
# 119  Grant of Patents (number)    NaN
# 122  Grant of Patents (number)    NaN
# 128  Grant of Patents (number)    NaN
# 130  Grant of Patents (number)    NaN
# 132  Grant of Patents (number)    NaN
# 134  Grant of Patents (number)    NaN
# 135  Grant of Patents (number)    NaN
# 136  Grant of Patents (number)    NaN
# 141  Grant of Patents (number)    NaN
# 142  Grant of Patents (number)    NaN
# 153  Grant of Patents (number)    NaN
# 160  Grant of Patents (number)    NaN
# 167  Grant of Patents (number)    NaN
# 172  Grant of Patents (number)    NaN
# 186  Grant of Patents (number)    NaN
# 191  Grant of Patents (number)    NaN
# 202  Grant of Patents (number)    NaN
# 212  Grant of Patents (number)    NaN
# 218  Grant of Patents (number)    NaN
# 219  Grant of Patents (number)    NaN
# 224  Grant of Patents (number)    NaN
# 225  Grant of Patents (number)    NaN
# 231  Grant of Patents (number)    NaN
# 245  Grant of Patents (number)    NaN
# 254  Grant of Patents (number)    NaN
# 257  Grant of Patents (number)    NaN
# 258  Grant of Patents (number)    NaN
# 265  Grant of Patents (number)    NaN
# 267  Grant of Patents (number)    NaN
# 269  Grant of Patents (number)    NaN
# 270  Grant of Patents (number)    NaN
# 271  Grant of Patents (number)    NaN
# 276  Grant of Patents (number)    NaN
# 278  Grant of Patents (number)    NaN
# 283  Grant of Patents (number)    NaN
# 289  Grant of Patents (number)    NaN
# 302  Grant of Patents (number)    NaN
# 318  Grant of Patents (number)    NaN
# 321  Grant of Patents (number)    NaN
# 335  Grant of Patents (number)    NaN
# 337  Grant of Patents (number)    NaN
# 354  Grant of Patents (number)    NaN
# 366  Grant of Patents (number)    NaN
# 387  Grant of Patents (number)    NaN
# 389  Grant of Patents (number)    NaN
# 390  Grant of Patents (number)    NaN
# 393  Grant of Patents (number)    NaN
# 398  Grant of Patents (number)    NaN
# 400  Grant of Patents (number)    NaN
# 405  Grant of Patents (number)    NaN
# 406  Grant of Patents (number)    NaN
# 411  Grant of Patents (number)    NaN
# 412  Grant of Patents (number)    NaN
# 413  Grant of Patents (number)    NaN
# 418  Grant of Patents (number)    NaN
# 430  Grant of Patents (number)    NaN
# 450  Grant of Patents (number)    NaN
# 453  Grant of Patents (number)    NaN
# 456  Grant of Patents (number)    NaN
# 461  Grant of Patents (number)    NaN
# 472  Grant of Patents (number)    NaN
# 479  Grant of Patents (number)    NaN
# 501  Grant of Patents (number)    NaN
# 506  Grant of Patents (number)    NaN
# 515  Grant of Patents (number)    NaN
# 519  Grant of Patents (number)    NaN
# 522  Grant of Patents (number)    NaN
# 524  Grant of Patents (number)    NaN
# 525  Grant of Patents (number)    NaN
# 528  Grant of Patents (number)    NaN
# 533  Grant of Patents (number)    NaN
# 535  Grant of Patents (number)    NaN

# %% [markdown]
# # Pivoting data to wide format for EDA

# %%
#Pivoting data to wide format for EDA
wide_gov_edu_expend_df = clean_gov_edu_expend_df.pivot_table(values='value',index=['country','year'],columns='indicator', aggfunc='first')
wide_gov_edu_expend_df.sample(n=10)
# Out:
# indicator               Government expenditure on lower secondary education as a percentage of GDP (%)  \
# country           year
# Sierra Leone      2016                                            0.09877
# Australia         2017                                            1.02643
# Republic of Korea 2017                                            0.79909
# Türkiye           2017                                            0.75873
# Austria           2017                                            1.17482
# Uruguay           2019                                            0.78387
# Latvia            2017                                            0.62762
# Uruguay           2017                                            0.81886
# Finland           2019                                            1.11942
# Slovakia          2017                                            0.89482
#
# indicator               Government expenditure on lower secondary education, US$ (millions)  \
# country           year
# Sierra Leone      2016                                            3.62966
# Australia         2017                                        13619.52842
# Republic of Korea 2017                                        12976.46577
# Türkiye           2017                                         6517.44093
# Austria           2017                                         4902.06158
# Uruguay           2019                                          479.97518
# Latvia            2017                                          191.32130
# Uruguay           2017                                          525.98497
# Finland           2019                                         3005.74365
# Slovakia          2017                                          853.60408
#
# indicator               Government expenditure on primary education as a percentage of GDP (%)  \
# country           year
# Sierra Leone      2016                                            1.09112
# Australia         2017                                            1.70813
# Republic of Korea 2017                                            1.39806
# Türkiye           2017                                            0.71206
# Austria           2017                                            0.90807
# Uruguay           2019                                            1.16214
# Latvia            2017                                            1.33690
# Uruguay           2017                                            1.03731
# Finland           2019                                            1.40851
# Slovakia          2017                                            0.88327
#
# indicator               Government expenditure on primary education, US$ (millions)  \
# country           year
# Sierra Leone      2016                                           40.09638
# Australia         2017                                        22664.92726
# Republic of Korea 2017                                        22703.06607
# Türkiye           2017                                         6116.58729
# Austria           2017                                         3789.00969
# Uruguay           2019                                          711.59312
# Latvia            2017                                          407.53812
# Uruguay           2017                                          666.30796
# Finland           2019                                         3781.95500
# Slovakia          2017                                          842.58423
#
# indicator               Government expenditure on upper secondary education as a percentage of GDP (%)  \
# country           year
# Sierra Leone      2016                                            0.26813
# Australia         2017                                            0.63267
# Republic of Korea 2017                                            0.90175
# Türkiye           2017                                            1.04228
# Austria           2017                                            0.94503
# Uruguay           2019                                            0.81101
# Latvia            2017                                            0.82574
# Uruguay           2017                                            0.73662
# Finland           2019                                            1.24833
# Slovakia          2017                                            0.80987
#
# indicator               Government expenditure on upper secondary education, US$ (millions)
# country           year
# Sierra Leone      2016                                            9.85331
# Australia         2017                                         8394.72585
# Republic of Korea 2017                                        14643.55723
# Türkiye           2017                                         8953.17889
# Austria           2017                                         3943.24731
# Uruguay           2019                                          496.58862
# Latvia            2017                                          251.71612
# Uruguay           2017                                          473.15971
# Finland           2019                                         3351.86183
# Slovakia          2017                                          772.56453

# %%
wide_gov_edu_expend_df.shape
# Out:
# (180, 6)

# %%
wide_gov_edu_expend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 180 entries, ('Argentina', 2016) to ('Uruguay', 2019)
# Data columns (total 6 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Government expenditure on lower secondary education as a percentage of GDP (%)  180 non-null    float64
#  1   Government expenditure on lower secondary education, US$ (millions)             180 non-null    float64
#  2   Government expenditure on primary education as a percentage of GDP (%)          180 non-null    float64
#  3   Government expenditure on primary education, US$ (millions)                     180 non-null    float64
#  4   Government expenditure on upper secondary education as a percentage of GDP (%)  180 non-null    float64
#  5   Government expenditure on upper secondary education, US$ (millions)             180 non-null    float64
# dtypes: float64(6)
# memory usage: 9.3+ KB

# %%
#Making columns lowercase and snakecase
wide_gov_edu_expend_df.columns = wide_gov_edu_expend_df.columns.str.lower()
wide_gov_edu_expend_df.rename(columns={'government expenditure on lower secondary education as a percentage of gdp (%)':'expenditure_lower_secondary_edu_gpd_percentage',
                                               'government expenditure on lower secondary education, us$ (millions)': 'expenditure_lower_secondary_edu_gpd_total',
                                               'government expenditure on primary education as a percentage of gdp (%)': 'expenditure_primary_edu_gpd_percentage',
                                               'government expenditure on primary education, us$ (millions)': 'expenditure_primary_edu_gpd_total',
                                               'government expenditure on upper secondary education as a percentage of gdp (%)':'expenditure_upper_secondary_edu_gpd_percentage',
                                               'government expenditure on upper secondary education, us$ (millions)': 'expenditure_upper_secondary_edu_gpd_total'}, inplace=True)

wide_gov_edu_expend_df.columns
# Out:
# Index(['expenditure_lower_secondary_edu_gpd_percentage',
#        'expenditure_lower_secondary_edu_gpd_total',
#        'expenditure_primary_edu_gpd_percentage',
#        'expenditure_primary_edu_gpd_total',
#        'expenditure_upper_secondary_edu_gpd_percentage',
#        'expenditure_upper_secondary_edu_gpd_total'],
#       dtype='object', name='indicator')

# %%
#Reordering columns
wide_gov_edu_expend_df = wide_gov_edu_expend_df.reindex(columns = ['expenditure_primary_edu_gpd_percentage', 'expenditure_lower_secondary_edu_gpd_percentage',
                                                                   'expenditure_upper_secondary_edu_gpd_percentage','expenditure_primary_edu_gpd_total',
                                                                   'expenditure_lower_secondary_edu_gpd_total', 'expenditure_upper_secondary_edu_gpd_total'])
wide_gov_edu_expend_df.head()
# Out:
# indicator       expenditure_primary_edu_gpd_percentage  \
# country   year
# Argentina 2016                                 1.66775
#           2017                                 1.61418
#           2018                                 1.43164
#           2019                                 1.49799
# Australia 2016                                 1.74398
#
# indicator       expenditure_lower_secondary_edu_gpd_percentage  \
# country   year
# Argentina 2016                                         1.33953
#           2017                                         1.27069
#           2018                                         1.06484
#           2019                                         0.99696
# Australia 2016                                         1.03826
#
# indicator       expenditure_upper_secondary_edu_gpd_percentage  \
# country   year
# Argentina 2016                                         0.93057
#           2017                                         0.88591
#           2018                                         0.71832
#           2019                                         0.72125
# Australia 2016                                         0.61508
#
# indicator       expenditure_primary_edu_gpd_total  \
# country   year
# Argentina 2016                         9298.23808
#           2017                        10389.34103
#           2018                         7513.50772
#           2019                         6783.16090
# Australia 2016                        21044.40239
#
# indicator       expenditure_lower_secondary_edu_gpd_total  \
# country   year
# Argentina 2016                                 7468.32290
#           2017                                 8178.54411
#           2018                                 5588.50285
#           2019                                 4514.40409
# Australia 2016                                12528.53399
#
# indicator       expenditure_upper_secondary_edu_gpd_total
# country   year
# Argentina 2016                                 5188.24135
#           2017                                 5701.98047
#           2018                                 3769.86380
#           2019                                 3265.93180
# Australia 2016                                 7422.04105

# %%
#Pivoting data to wide format for EDA
wide_gdp_df = clean_gdp_df.pivot_table(values='value',index=['country','year'],columns='indicator', aggfunc='first')
wide_gdp_df.sample(n=10)
# Out:
# indicator                GDP (current US$)  GDP growth (annual %)  \
# country            year
# Hungary            2016       1.286360e+11                    2.2
# Netherlands        2016       7.840600e+11                    2.2
# Norway             2018       4.370000e+11                    1.1
# Sierra Leone       2017       3.719369e+09                    4.2
# Iceland            2017       2.472829e+10                    4.2
# Romania            2018       2.414570e+11                    4.5
# South Africa       2019       3.879350e+11                    0.1
# Dominican Republic 2016       7.570472e+10                    6.7
# Chile              2019       2.785850e+11                    0.8
# El Salvador        2017       2.497919e+10                    2.2
#
# indicator                GDP per capita (current US$)
# country            year
# Hungary            2016                       13107.0
# Netherlands        2016                       46039.0
# Norway             2018                       82268.0
# Sierra Leone       2017                         497.0
# Iceland            2017                       72010.0
# Romania            2018                       12399.0
# South Africa       2019                        6625.0
# Dominican Republic 2016                        7281.0
# Chile              2019                       14699.0
# El Salvador        2017                        3910.0

# %%
wide_gdp_df.shape
# Out:
# (180, 3)

# %%
wide_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 180 entries, ('Argentina', 2016) to ('Uruguay', 2019)
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GDP (current US$)             180 non-null    float64
#  1   GDP growth (annual %)         180 non-null    float64
#  2   GDP per capita (current US$)  180 non-null    float64
# dtypes: float64(3)
# memory usage: 5.1+ KB

# %%
#Making columns lowercase and snakecase
wide_gdp_df.columns = wide_gdp_df.columns.str.lower()
wide_gdp_df.rename(columns={'GDP (current US$)':'gdp',
                                               'GDP growth (annual %)': 'annual_gdp_growth_percent',
                                               'GDP per capita (current US$)': 'gdp_per_capita',}, inplace=True)

wide_gdp_df.columns
# Out:
# Index(['gdp (current us$)', 'gdp growth (annual %)',
#        'gdp per capita (current us$)'],
#       dtype='object', name='indicator')

# %%
#Pivoting data to wide format for EDA
wide_internet_df = clean_internet_df.pivot_table(values='value',index=['country','year'],columns='indicator', aggfunc='first')
wide_internet_df.sample(n=10)
# Out:
# indicator         Individuals using the Internet (% of population)
# country     year
# Belgium     2019                                         90.275430
# Sweden      2018                                         89.246963
# Spain       2017                                         84.602246
# Lithuania   2018                                         79.722583
# El Salvador 2018                                         43.800000
# Japan       2018                                         91.280000
# Greece      2019                                         75.671207
# Japan       2019                                         92.730398
# Belize      2018                                         49.800000
# Türkiye     2017                                         64.684618

# %%
wide_internet_df.shape
# Out:
# (180, 1)

# %%
wide_internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 180 entries, ('Argentina', 2016) to ('Uruguay', 2019)
# Data columns (total 1 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Individuals using the Internet (% of population)  180 non-null    float64
# dtypes: float64(1)
# memory usage: 2.2+ KB

# %%
#Making columns lowercase and snakecase
wide_internet_df.rename(columns={'Individuals using the Internet (% of population)': 'percent_population_internet_usage'}, inplace=True)

wide_internet_df.columns
# Out:
# Index(['percent_population_internet_usage'], dtype='object', name='indicator')

# %%
#Pivoting data to wide format for EDA
wide_patents_df = patents_df.pivot_table(values='Value',index=['Country','Year'],columns='Series', aggfunc='first')
wide_patents_df.sample(n=10)
# Out:
# Series                        Grants of patents (number)  \
# Country                  Year
# Cyprus                   2005                         68
# Panama                   2020                        284
# Portugal                 2019                         80
# United States of America 2018                    307,759
# Spain                    2018                      1,760
# Saudi Arabia             2019                        480
# Israel                   2010                      2,293
# Switzerland              2018                        614
# Ecuador                  2019                         17
# Germany                  2020                     17,305
#
# Series                        Patents in force (number)  \
# Country                  Year
# Cyprus                   2005                       NaN
# Panama                   2020                     1,490
# Portugal                 2019                    40,052
# United States of America 2018                 3,063,494
# Spain                    2018                    95,911
# Saudi Arabia             2019                     3,829
# Israel                   2010                    26,494
# Switzerland              2018                   244,581
# Ecuador                  2019                        71
# Germany                  2020                   834,734
#
# Series                        Resident patent filings (per million population)
# Country                  Year
# Cyprus                   2005                                              NaN
# Panama                   2020                                              NaN
# Portugal                 2019                                               95
# United States of America 2018                                              872
# Spain                    2018                                               71
# Saudi Arabia             2019                                               50
# Israel                   2010                                              190
# Switzerland              2018                                            1,081
# Ecuador                  2019                                                2
# Germany                  2020                                              819

# %%
wide_patents_df.shape
# Out:
# (844, 3)

# %%
wide_patents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 844 entries, ('Africa', 2005) to ('Zimbabwe', 2020)
# Data columns (total 3 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Grants of patents (number)                        786 non-null    object
#  1   Patents in force (number)                         463 non-null    object
#  2   Resident patent filings (per million population)  490 non-null    object
# dtypes: object(3)
# memory usage: 23.7+ KB

# %%
#Pivoting data to wide format for EDA
wide_research_df = research_df.pivot_table(values='Value',index=['Country','Year'],columns='Series', aggfunc='first')
wide_research_df.sample(n=10)
# Out:
# Series            R & D personnel: Other supporting staff - total (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                253
# Italy        2015                                                NaN
# France       2018                                                NaN
# Poland       2010                                              6,393
# Bulgaria     2010                                              1,891
# Armenia      2005                                              1,491
# Ethiopia     2007                                              3,458
# Mozambique   2010                                                159
# Saint Helena 2000                                                NaN
# Benin        2007                                                NaN
#
# Series            R & D personnel: Other supporting staff - women (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                NaN
# Italy        2015                                                NaN
# France       2018                                                NaN
# Poland       2010                                                NaN
# Bulgaria     2010                                              1,172
# Armenia      2005                                                NaN
# Ethiopia     2007                                                NaN
# Mozambique   2010                                                NaN
# Saint Helena 2000                                                NaN
# Benin        2007                                                NaN
#
# Series            R & D personnel: Researchers - total (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                374
# Italy        2015                                            125,875
# France       2018                                            306,451
# Poland       2010                                             64,511
# Bulgaria     2010                                             10,979
# Armenia      2005                                              5,056
# Ethiopia     2007                                              1,615
# Mozambique   2010                                                912
# Saint Helena 2000                                                NaN
# Benin        2007                                              1,000
#
# Series            R & D personnel: Researchers - women (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                 56
# Italy        2015                                             45,447
# France       2018                                                NaN
# Poland       2010                                             24,745
# Bulgaria     2010                                              5,506
# Armenia      2005                                              2,329
# Ethiopia     2007                                                125
# Mozambique   2010                                                294
# Saint Helena 2000                                                NaN
# Benin        2007                                                NaN
#
# Series            R & D personnel: Technicians - total (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                117
# Italy        2015                                                NaN
# France       2018                                                NaN
# Poland       2010                                             10,939
# Bulgaria     2010                                              3,704
# Armenia      2005                                                345
# Ethiopia     2007                                                978
# Mozambique   2010                                              1,093
# Saint Helena 2000                                                  8
# Benin        2007                                                NaN
#
# Series            R & D personnel: Technicians - women (number in full-time equivalent)  \
# Country      Year
# Burundi      2010                                                NaN
# Italy        2015                                                NaN
# France       2018                                                NaN
# Poland       2010                                                NaN
# Bulgaria     2010                                              2,189
# Armenia      2005                                                NaN
# Ethiopia     2007                                                NaN
# Mozambique   2010                                                NaN
# Saint Helena 2000                                                  4
# Benin        2007                                                NaN
#
# Series            R & D personnel: Total (number in full-time equivalent)
# Country      Year
# Burundi      2010                                                744
# Italy        2015                                            259,167
# France       2018                                            451,423
# Poland       2010                                             81,843
# Bulgaria     2010                                             16,574
# Armenia      2005                                              6,892
# Ethiopia     2007                                              6,051
# Mozambique   2010                                              2,164
# Saint Helena 2000                                                NaN
# Benin        2007                                                NaN

# %%
wide_research_df.shape
# Out:
# (519, 7)

# %%
wide_research_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 519 entries, ('Albania', 2008) to ('Zimbabwe', 2012)
# Data columns (total 7 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   R & D personnel: Other supporting staff - total (number in full-time equivalent)  380 non-null    object
#  1   R & D personnel: Other supporting staff - women (number in full-time equivalent)  241 non-null    object
#  2   R & D personnel: Researchers - total (number in full-time equivalent)             497 non-null    object
#  3   R & D personnel: Researchers - women (number in full-time equivalent)             355 non-null    object
#  4   R & D personnel: Technicians - total (number in full-time equivalent)             405 non-null    object
#  5   R & D personnel: Technicians - women (number in full-time equivalent)             245 non-null    object
#  6   R & D personnel: Total (number in full-time equivalent)                           449 non-null    object
# dtypes: object(7)
# memory usage: 31.4+ KB

# %%
#Pivoting data to wide format for EDA
wide_imports_exports_df = imports_exports_df.pivot_table(values='Value',index=['Country','Year'],columns='Series', aggfunc='first')
wide_imports_exports_df.sample(n=10)
# Out:
# Series                        Balance imports/exports (millions of US dollars)  \
# Country                  Year
# United States of America 2021                                        1,179,839
# Kiribati                 2010                                              -69
# Central African Republic 2015                                             -360
# Niger                    2020                                           -1,782
# India                    2015                                         -126,364
# Austria                  2020                                           -2,490
# Iraq                     2020                                           23,018
# Guinea                   2005                                             -852
# Tunisia                  1995                                           -2,428
# Czechia                  2021                                           15,322
#
# Series                        Exports FOB (millions of US dollars)  \
# Country                  Year
# United States of America 2021                                  NaN
# Kiribati                 2010                                    4
# Central African Republic 2015                                   97
# Niger                    2020                                1,246
# India                    2015                              264,381
# Austria                  2020                              162,145
# Iraq                     2020                               59,248
# Guinea                   2005                                  796
# Tunisia                  1995                                5,475
# Czechia                  2021                              227,161
#
# Series                        Imports CIF (millions of US dollars)
# Country                  Year
# United States of America 2021                                  NaN
# Kiribati                 2010                                   73
# Central African Republic 2015                                  457
# Niger                    2020                                3,028
# India                    2015                              390,745
# Austria                  2020                              164,636
# Iraq                     2020                               36,231
# Guinea                   2005                                1,648
# Tunisia                  1995                                7,903
# Czechia                  2021                              211,839

# %%
wide_imports_exports_df.shape
# Out:
# (1687, 3)

# %%
wide_imports_exports_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1687 entries, ('Afghanistan', 2010) to ('Zimbabwe', 2021)
# Data columns (total 3 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Balance imports/exports (millions of US dollars)  1687 non-null   object
#  1   Exports FOB (millions of US dollars)              1686 non-null   object
#  2   Imports CIF (millions of US dollars)              1686 non-null   object
# dtypes: object(3)
# memory usage: 46.6+ KB

# %% [markdown]
# # Data Cleaning
# Proposed Steps
# - All
# 1. Drop countries that will not be used in analysis
# - wide_edu_df (loaded this by accident. I think we may be able to delete this dataset entirely):
# 1. Drop the "Gross enrollment ratio" columns, unless we want to dive into enrollment rates among boys and girls.
# 2. Change data types of all columns from object to float
# - wide_public_expend_df:
# 1. No changes. May be able to drop the Internet usage dataset in favor of the three columns on internet usage in this dataset.
# - wide_gdp_df:
# 1. GDP in constant 2010 prices (millions of US dollars), GDP in current prices (millions of US dollars), and GDP per capita (US dollars) columns need data type changed from object to int
# 2. GDP real rates of growth (percent) column data type changed from object to float
# - wide_internet_df:
# 1. The internet usage columns in the wide_public_expend_df might be a better fit. Suggesting that we do not use this dataset.
# - wide_patents_df:
# 1. Change data types of all columns from object to float
# - wide_research-df:
# 1. Change data types of all columns from object to int
# - wide_imports_exports_df:
# 1. Change data types of all columns from object to int

# %%
#dropping NaN values from public expenditure df to get countries that have needed info
wide_public_edu_expend_df.drop(columns=['All staff compensation as % of total expenditure in public institutions (%)','Capital expenditure as % of total expenditure in public institutions (%)', 
                               'Current expenditure other than staff compensation as % of total expenditure in public institutions (%)'], axis = 1,inplace=True)
wide_public_edu_expend_df.head()
# Out:
# Series            Basic access to computers by level of education: Lower secondary  \
# Country     Year
# Afghanistan 2010                                                NaN
#             2015                                                NaN
#             2019                                               10.0
# Albania     2005                                                NaN
#             2007                                                NaN
#
# Series            Basic access to computers by level of education: Primary  \
# Country     Year
# Afghanistan 2010                                                NaN
#             2015                                                NaN
#             2019                                                9.0
# Albania     2005                                                NaN
#             2007                                                NaN
#
# Series            Basic access to computers by level of education: Upper secondary  \
# Country     Year
# Afghanistan 2010                                                NaN
#             2015                                                NaN
#             2019                                               23.0
# Albania     2005                                                NaN
#             2007                                                NaN
#
# Series            Public expenditure on education (% of GDP)
# Country     Year
# Afghanistan 2010                                         3.5
#             2015                                         3.3
#             2019                                         3.2
# Albania     2005                                         3.3
#             2007                                         3.3

# %%
wide_public_edu_expend_df.dropna(inplace=True)
wide_public_edu_expend_df.head(5)
# Out:
# Series                    Basic access to computers by level of education: Lower secondary  \
# Country             Year
# Afghanistan         2019                                               10.0
# Albania             2019                                               83.0
# Andorra             2019                                              100.0
# Angola              2016                                               25.0
# Antigua and Barbuda 2018                                              100.0
#
# Series                    Basic access to computers by level of education: Primary  \
# Country             Year
# Afghanistan         2019                                                9.0
# Albania             2019                                               49.0
# Andorra             2019                                              100.0
# Angola              2016                                                7.0
# Antigua and Barbuda 2018                                               90.0
#
# Series                    Basic access to computers by level of education: Upper secondary  \
# Country             Year
# Afghanistan         2019                                               23.0
# Albania             2019                                               82.0
# Andorra             2019                                              100.0
# Angola              2016                                               49.0
# Antigua and Barbuda 2018                                              100.0
#
# Series                    Public expenditure on education (% of GDP)
# Country             Year
# Afghanistan         2019                                         3.2
# Albania             2019                                         3.9
# Andorra             2019                                         3.2
# Angola              2016                                         2.8
# Antigua and Barbuda 2018                                         2.6

# %%
wide_public_edu_expend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 144 entries, ('Afghanistan', 2019) to ('Zimbabwe', 2018)
# Data columns (total 4 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Basic access to computers by level of education: Lower secondary  144 non-null    float64
#  1   Basic access to computers by level of education: Primary          144 non-null    float64
#  2   Basic access to computers by level of education: Upper secondary  144 non-null    float64
#  3   Public expenditure on education (% of GDP)                        144 non-null    float64
# dtypes: float64(4)
# memory usage: 6.8+ KB

# %%
wide_public_edu_expend_df.reset_index(inplace=True)

#getting values counts to see how many years each country has
wide_public_edu_expend_df['Country'].value_counts()
# Out:
# Poland                        4
# Netherlands                   4
# Estonia                       4
# Hungary                       4
# Australia                     4
# Finland                       4
# Slovenia                      4
# Portugal                      4
# Rwanda                        3
# Norway                        3
# Argentina                     3
# Saint Lucia                   3
# Belgium                       3
# Spain                         3
# Zimbabwe                      2
# Qatar                         2
# Cook Islands                  2
# Philippines                   2
# Israel                        2
# Jordan                        2
# El Salvador                   2
# Ecuador                       2
# Switzerland                   2
# Seychelles                    2
# Thailand                      2
# State of Palestine            2
# Brazil                        2
# British Virgin Islands        2
# Slovakia                      2
# Uruguay                       1
# Niger                         1
# Paraguay                      1
# Nepal                         1
# United Arab Emirates          1
# Ukraine                       1
# Myanmar                       1
# Montserrat                    1
# Turks and Caicos Islands      1
# Monaco                        1
# Oman                          1
# Senegal                       1
# Peru                          1
# Turkmenistan                  1
# Sao Tome and Principe         1
# Republic of Korea             1
# Republic of Moldova           1
# Singapore                     1
# Sierra Leone                  1
# Saint Vincent & Grenadines    1
# Mauritania                    1
# Samoa                         1
# San Marino                    1
# Mauritius                     1
# Afghanistan                   1
# Maldives                      1
# Burkina Faso                  1
# Cuba                          1
# Costa Rica                    1
# Congo                         1
# China, Macao SAR              1
# China, Hong Kong SAR          1
# China                         1
# Cabo Verde                    1
# Belarus                       1
# Dominica                      1
# Bahrain                       1
# Azerbaijan                    1
# Aruba                         1
# Armenia                       1
# Antigua and Barbuda           1
# Angola                        1
# Andorra                       1
# Dem. Rep. of the Congo        1
# Egypt                         1
# Malaysia                      1
# Indonesia                     1
# Madagascar                    1
# Lebanon                       1
# Latvia                        1
# Kyrgyzstan                    1
# Albania                       1
# Jamaica                       1
# Iran (Islamic Republic of)    1
# India                         1
# Eswatini                      1
# Guinea                        1
# Guatemala                     1
# Grenada                       1
# Ghana                         1
# Georgia                       1
# Gambia                        1
# France                        1
# Kuwait                        1
# Name: Country, dtype: int64

# %%
#showing rows that have countries with more 3 or more years of data

country_data_df=wide_public_edu_expend_df[wide_public_edu_expend_df['Country'].isin(
    wide_public_edu_expend_df['Country'].value_counts()[wide_public_edu_expend_df['Country'].value_counts() > 2].index)]

country_data_df.head()
# Out:
# Series    Country  Year  \
# 5       Argentina  2009
# 6       Argentina  2015
# 7       Argentina  2019
# 10      Australia  2005
# 11      Australia  2010
#
# Series  Basic access to computers by level of education: Lower secondary  \
# 5                                                    54.0
# 6                                                    72.0
# 7                                                    55.0
# 10                                                  100.0
# 11                                                  100.0
#
# Series  Basic access to computers by level of education: Primary  \
# 5                                                    37.8
# 6                                                    58.7
# 7                                                    66.3
# 10                                                  100.0
# 11                                                  100.0
#
# Series  Basic access to computers by level of education: Upper secondary  \
# 5                                                    77.0
# 6                                                    75.0
# 7                                                    59.0
# 10                                                  100.0
# 11                                                  100.0
#
# Series  Public expenditure on education (% of GDP)
# 5                                              5.5
# 6                                              5.8
# 7                                              4.8
# 10                                             4.9
# 11                                             5.6

# %%
#Number of countries for each year
country_data_df['Year'].value_counts()
# Out:
# 2015    13
# 2010    12
# 2005     8
# 2018     7
# 2016     6
# 2019     2
# 2009     1
# 2020     1
# Name: Year, dtype: int64

# %%
#Creating countries in each year as a set
countries_2005 = set(country_data_df[country_data_df['Year'] == 2005]['Country'].values)
countries_2010 = set(country_data_df[country_data_df['Year'] == 2010]['Country'].values)
countries_2015 = set(country_data_df[country_data_df['Year'] == 2015]['Country'].values)
countries_2016 = set(country_data_df[country_data_df['Year'] == 2016]['Country'].values)
countries_2018 = set(country_data_df[country_data_df['Year'] == 2018]['Country'].values)

# %%
#All the countries have data for 2010, 2015, and 2018
countries = countries_2010.intersection(countries_2015).intersection(countries_2018)
countries
# Out:
# {'Belgium', 'Finland', 'Netherlands', 'Norway', 'Portugal', 'Spain'}

# %%
#
cleaned_public_edu_expend = country_data_df[country_data_df['Country'].isin(countries)]
cleaned_public_edu_expend
# Out:
# Series      Country  Year  \
# 17          Belgium  2010
# 18          Belgium  2015
# 19          Belgium  2018
# 46          Finland  2005
# 47          Finland  2010
# 48          Finland  2015
# 49          Finland  2018
# 82      Netherlands  2005
# 83      Netherlands  2010
# 84      Netherlands  2015
# 85      Netherlands  2018
# 87           Norway  2010
# 88           Norway  2015
# 89           Norway  2018
# 99         Portugal  2005
# 100        Portugal  2010
# 101        Portugal  2015
# 102        Portugal  2018
# 128           Spain  2010
# 129           Spain  2015
# 130           Spain  2018
#
# Series  Basic access to computers by level of education: Lower secondary  \
# 17                                                  100.0
# 18                                                  100.0
# 19                                                  100.0
# 46                                                  100.0
# 47                                                  100.0
# 48                                                  100.0
# 49                                                  100.0
# 82                                                  100.0
# 83                                                  100.0
# 84                                                  100.0
# 85                                                  100.0
# 87                                                  100.0
# 88                                                  100.0
# 89                                                  100.0
# 99                                                  100.0
# 100                                                 100.0
# 101                                                 100.0
# 102                                                 100.0
# 128                                                 100.0
# 129                                                 100.0
# 130                                                 100.0
#
# Series  Basic access to computers by level of education: Primary  \
# 17                                                  100.0
# 18                                                  100.0
# 19                                                  100.0
# 46                                                  100.0
# 47                                                  100.0
# 48                                                  100.0
# 49                                                  100.0
# 82                                                  100.0
# 83                                                  100.0
# 84                                                  100.0
# 85                                                  100.0
# 87                                                  100.0
# 88                                                  100.0
# 89                                                  100.0
# 99                                                  100.0
# 100                                                 100.0
# 101                                                 100.0
# 102                                                 100.0
# 128                                                 100.0
# 129                                                 100.0
# 130                                                 100.0
#
# Series  Basic access to computers by level of education: Upper secondary  \
# 17                                                  100.0
# 18                                                  100.0
# 19                                                  100.0
# 46                                                  100.0
# 47                                                  100.0
# 48                                                  100.0
# 49                                                  100.0
# 82                                                  100.0
# 83                                                  100.0
# 84                                                  100.0
# 85                                                  100.0
# 87                                                  100.0
# 88                                                  100.0
# 89                                                  100.0
# 99                                                  100.0
# 100                                                 100.0
# 101                                                 100.0
# 102                                                 100.0
# 128                                                 100.0
# 129                                                 100.0
# 130                                                 100.0
#
# Series  Public expenditure on education (% of GDP)
# 17                                             6.4
# 18                                             6.5
# 19                                             6.4
# 46                                             6.0
# 47                                             6.5
# 48                                             7.0
# 49                                             6.3
# 82                                             5.1
# 83                                             5.5
# 84                                             5.3
# 85                                             5.4
# 87                                             6.7
# 88                                             7.6
# 89                                             7.6
# 99                                             5.1
# 100                                            5.4
# 101                                            4.9
# 102                                            4.7
# 128                                            4.9
# 129                                            4.3
# 130                                            4.2
